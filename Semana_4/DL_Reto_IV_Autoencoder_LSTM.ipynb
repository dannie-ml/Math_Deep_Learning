# %% [markdown]
# # Detección de anomalias usando Autoencoders
#
# **Contexto:**
#
# Usaremos el conjunto de datos Numenta Anomaly Benchmark (NAB). Este proporciona series de tiempo artificiales que contienen períodos anómalos de comportamiento etiquetados. Los datos están ordenados, tienen marcas de tiempo y son métricas de un solo valor.
#
# Usaremos el archivo `art_daily_small_noise.csv` para el entrenamiento y el archivo `art_daily_jumpsup.csv` para las pruebas.
#
# La simplicidad de este conjunto de datos nos permite demostrar la detección de anomalías de manera efectiva.

# %% [markdown]
# # Librerias

# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers

from matplotlib import pyplot as plt

# %% [markdown]
# # Cargamos datos

# %%
master_url_root = "https://raw.githubusercontent.com/numenta/NAB/master/data/"

df_small_noise_url_suffix = "artificialNoAnomaly/art_daily_small_noise.csv"
df_small_noise_url = master_url_root + df_small_noise_url_suffix
df_small_noise = pd.read_csv(
    df_small_noise_url, parse_dates=True, index_col="timestamp"
)

df_daily_jumpsup_url_suffix = "artificialWithAnomaly/art_daily_jumpsup.csv"
df_daily_jumpsup_url = master_url_root + df_daily_jumpsup_url_suffix
df_daily_jumpsup = pd.read_csv(
    df_daily_jumpsup_url, parse_dates=True, index_col="timestamp"
)

# %%
# Entrenamiento / Training
print(df_small_noise.head())

# Prueba / Test
print(df_daily_jumpsup.head())
# Out:
#                          value
# timestamp
# 2014-04-01 00:00:00  18.324919
# 2014-04-01 00:05:00  21.970327
# 2014-04-01 00:10:00  18.624806
# 2014-04-01 00:15:00  21.953684
# 2014-04-01 00:20:00  21.909120
#                          value
# timestamp
# 2014-04-01 00:00:00  19.761252
# 2014-04-01 00:05:00  20.500833
# 2014-04-01 00:10:00  19.961641
# 2014-04-01 00:15:00  21.490266
# 2014-04-01 00:20:00  20.187739

# %% [markdown]
# # Visualizacion de datos

# %% [markdown]
# #### Series sin anomalías

# %%
fig, ax = plt.subplots()
df_small_noise.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# #### Series con anomalías

# %%
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# # Preprocesamiento de los datos
#
# Obtenemos los valores del archivo de datos de la serie de tiempo de entrenamiento y normalizamos los datos de `value`. Tenemos un `value` cada 5 minutos durante 14 días.
#
# - 24 * 60 / 5 = **288 pasos de tiempo por día**
# - 288 * 14 = **4032 puntos de datos** en total"

# %%
# Normalize and save the mean and std we get, for normalizing test data.

training_mean = df_small_noise.mean()
training_std = df_small_noise.std()
df_training_value = (df_small_noise - training_mean) / training_std
print("Número de ejemplos de entrenamiento:", len(df_training_value))
# Out:
# Número de ejemplos de entrenamiento: 4032

# %% [markdown]
# #### Creación de secuencias

# %%
TIME_STEPS = 288
# Create sequences combining TIME_STEPS contiguous data values from the training data.

# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)

x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)
# Out:
# Training input shape:  (3745, 288, 1)

# %% [markdown]
# # Construcción del modelo.
#
# We will build a convolutional reconstruction autoencoder model. The model will take input of shape (batch_size, sequence_length, num_features) and return output of the same shape. In this case, sequence_length is 288 and num_features is 1

# %%
model = tf.keras.Sequential(
    [
        layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
        
        # Encoder
        layers.LSTM(64, return_sequences=True, activation="tanh"),
        layers.Dropout(rate=0.2),
        layers.LSTM(32, return_sequences=False, activation="tanh"),

        # Bottleneck
        layers.RepeatVector(TIME_STEPS),

        # Decoder
        layers.LSTM(32, return_sequences=True, activation="tanh"),
        layers.Dropout(rate=0.2),
        layers.LSTM(64, return_sequences=True, activation="tanh"),

        layers.TimeDistributed(layers.Dense(x_train.shape[2])),
    ]
)

model.compile(optimizer = optimizers.Adam(learning_rate=1e-3), loss="mse")
model.summary()
# Out:
# 2026-01-13 12:50:58.689820: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2026-01-13 12:50:58.689846: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-01-13 12:50:58.689852: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-01-13 12:50:58.689881: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-01-13 12:50:58.689895: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 288, 64)           16896
#
#  dropout (Dropout)           (None, 288, 64)           0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  repeat_vector (RepeatVecto  (None, 288, 32)           0
#  r)
#
#  lstm_2 (LSTM)               (None, 288, 32)           8320
#
#  dropout_1 (Dropout)         (None, 288, 32)           0
#
#  lstm_3 (LSTM)               (None, 288, 64)           24832
#
#  time_distributed (TimeDist  (None, 288, 1)            65
#  ributed)
#
# =================================================================
# Total params: 62529 (244.25 KB)
# Trainable params: 62529 (244.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Entrenamiento del modelo
#
# Please note that we are using `x_train` as both the input and the target since this is a reconstruction model.

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.1,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss", 
            patience=5, 
            mode="min"
        )
    ],
)
# Out:
# Epoch 1/50
# 2026-01-13 12:51:01.190836: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2026-01-13 12:51:01.367346: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 27/27 [==============================] - 7s 127ms/step - loss: 0.9742 - val_loss: 0.9701
# Epoch 2/50
# 27/27 [==============================] - 2s 83ms/step - loss: 0.9242 - val_loss: 0.9400
# Epoch 3/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.8836 - val_loss: 0.8913
# Epoch 4/50
# 27/27 [==============================] - 2s 88ms/step - loss: 0.8968 - val_loss: 0.9344
# Epoch 5/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.8515 - val_loss: 0.8938
# Epoch 6/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.8475 - val_loss: 0.8336
# Epoch 7/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.8242 - val_loss: 0.8054
# Epoch 8/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.8369 - val_loss: 0.8926
# Epoch 9/50
# 27/27 [==============================] - 2s 89ms/step - loss: 0.7989 - val_loss: 0.7630
# Epoch 10/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.7471 - val_loss: 0.7742
# Epoch 11/50
# 27/27 [==============================] - 2s 85ms/step - loss: 0.6812 - val_loss: 0.6853
# Epoch 12/50
# 27/27 [==============================] - 2s 84ms/step - loss: 0.6419 - val_loss: 0.6576
# Epoch 13/50
# 27/27 [==============================] - 2s 84ms/step - loss: 0.6213 - val_loss: 0.6448
# Epoch 14/50
# 27/27 [==============================] - 2s 83ms/step - loss: 0.7068 - val_loss: 0.7168
# Epoch 15/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.6487 - val_loss: 0.6349
# Epoch 16/50
# 27/27 [==============================] - 2s 83ms/step - loss: 0.6110 - val_loss: 0.6023
# Epoch 17/50
# 27/27 [==============================] - 2s 84ms/step - loss: 0.6295 - val_loss: 0.5594
# Epoch 18/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.5382 - val_loss: 0.4817
# Epoch 19/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4714 - val_loss: 0.4105
# Epoch 20/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3665 - val_loss: 0.4095
# Epoch 21/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4052 - val_loss: 0.4198
# Epoch 22/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.3418 - val_loss: 0.2999
# Epoch 23/50
# 27/27 [==============================] - 2s 83ms/step - loss: 0.3256 - val_loss: 0.1742
# Epoch 24/50
# 27/27 [==============================] - 2s 83ms/step - loss: 0.6746 - val_loss: 0.9368
# Epoch 25/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.8170 - val_loss: 0.6955
# Epoch 26/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.4972 - val_loss: 0.2920
# Epoch 27/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.1794 - val_loss: 0.1213
# Epoch 28/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.1085 - val_loss: 0.0876
# Epoch 29/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0963 - val_loss: 0.1800
# Epoch 30/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.1252 - val_loss: 0.0926
# Epoch 31/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0797 - val_loss: 0.0649
# Epoch 32/50
# 27/27 [==============================] - 2s 83ms/step - loss: 0.0735 - val_loss: 0.0641
# Epoch 33/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0764 - val_loss: 0.0622
# Epoch 34/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0763 - val_loss: 0.0561
# Epoch 35/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0644 - val_loss: 0.0530
# Epoch 36/50
# 27/27 [==============================] - 2s 82ms/step - loss: 0.0614 - val_loss: 0.0525
# Epoch 37/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0607 - val_loss: 0.0493
# Epoch 38/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0595 - val_loss: 0.0658
# Epoch 39/50
# 27/27 [==============================] - 2s 83ms/step - loss: 0.0627 - val_loss: 0.0552
# Epoch 40/50
# 27/27 [==============================] - 2s 87ms/step - loss: 0.0613 - val_loss: 0.0531
# Epoch 41/50
# 27/27 [==============================] - 2s 85ms/step - loss: 0.0615 - val_loss: 0.0490
# Epoch 42/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0566 - val_loss: 0.0624
# Epoch 43/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0594 - val_loss: 0.0555
# Epoch 44/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0594 - val_loss: 0.0662
# Epoch 45/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0682 - val_loss: 0.0462
# Epoch 46/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0548 - val_loss: 0.0467
# Epoch 47/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0535 - val_loss: 0.0454
# Epoch 48/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0541 - val_loss: 0.0422
# Epoch 49/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0530 - val_loss: 0.0396
# Epoch 50/50
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0520 - val_loss: 0.0435

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Detectando anomalías.

# %% [markdown]
# Detectaremos anomalías determinando qué tan bien nuestro modelo puede reconstruir los datos de entrada.
#
# 1. Calcular la pérdida **MAE** en las muestras de entrenamiento.
# 2. Encontrar el valor máximo de la pérdida **MAE**. Este es el peor desempeño de nuestro modelo al intentar reconstruir una muestra. Usaremos este valor como el `umbral` para la detección de anomalías.
# 3. Si la pérdida de reconstrucción para una muestra es mayor que este valor `umbral`, entonces podemos inferir que el modelo está observando un patrón con el que no está familiarizado. Etiquetaremos esta muestra como una `anomalía`.

# %%
# Obtenemos el MAE.
x_train_pred = model.predict(x_train)
train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

threshold = np.max(train_mae_loss)
print("Reconstrucción del umbral de error: ", threshold)
# Out:
# 118/118 [==============================] - 3s 21ms/step
# Reconstrucción del umbral de error:  0.15641938742243552

# %% [markdown]
# ## Comparar reconstrucción
#
# Veamos cómo nuestro modelo ha reconstruido la primera muestra. Esta corresponde a los **288 pasos de tiempo del día 1** de nuestro conjunto de entrenamiento.

# %%
# Checking how the first sequence is learnt
plt.plot(x_train[0])
plt.plot(x_train_pred[0])
plt.show()

# %% [markdown]
# ## Preparando el conjunto de datos de TEST

# %%
df_test_value = (df_daily_jumpsup - training_mean) / training_std
fig, ax = plt.subplots()
df_test_value.plot(legend=False, ax=ax)
plt.show()

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)

# Get test MAE loss.
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
test_mae_loss = test_mae_loss.reshape((-1))

plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# Detect all the samples which are anomalies.
anomalies = test_mae_loss > threshold
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# Test input shape:  (3745, 288, 1)
# 118/118 [==============================] - 2s 21ms/step
# Number of anomaly samples:  391
# Indices of anomaly samples:  (array([ 207,  208, 2704, 2705, 2706, 2707, 2708, 2709, 2710, 2711, 2712,
#        2713, 2714, 2715, 2716, 2717, 2718, 2719, 2720, 2721, 2722, 2723,
#        2724, 2725, 2726, 2727, 2728, 2729, 2730, 2731, 2732, 2733, 2734,
#        2735, 2736, 2737, 2738, 2739, 2740, 2741, 2742, 2743, 2744, 2745,
#        2746, 2747, 2748, 2749, 2750, 2751, 2752, 2753, 2754, 2755, 2756,
#        2757, 2758, 2759, 2760, 2761, 2762, 2763, 2764, 2765, 2766, 2767,
#        2768, 2769, 2770, 2771, 2772, 2773, 2774, 2775, 2776, 2777, 2778,
#        2779, 2780, 2781, 2782, 2783, 2784, 2785, 2786, 2787, 2788, 2789,
#        2790, 2791, 2792, 2793, 2794, 2795, 2796, 2797, 2798, 2799, 2800,
#        2801, 2802, 2803, 2804, 2805, 2806, 2807, 2808, 2809, 2810, 2811,
#        2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 2820, 2821, 2822,
#        2823, 2824, 2825, 2826, 2827, 2828, 2829, 2830, 2831, 2832, 2833,
#        2834, 2835, 2836, 2837, 2838, 2839, 2840, 2841, 2842, 2843, 2844,
#        2845, 2846, 2847, 2848, 2849, 2850, 2851, 2852, 2853, 2854, 2855,
#        2856, 2857, 2858, 2859, 2860, 2861, 2862, 2863, 2864, 2865, 2866,
#        2867, 2868, 2869, 2870, 2871, 2872, 2873, 2874, 2875, 2876, 2877,
#        2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888,
#        2889, 2890, 2891, 2892, 2893, 2894, 2895, 2896, 2897, 2898, 2899,
#        2900, 2901, 2902, 2903, 2904, 2905, 2906, 2907, 2908, 2909, 2910,
#        2911, 2912, 2913, 2914, 2915, 2916, 2917, 2918, 2919, 2920, 2921,
#        2922, 2923, 2924, 2925, 2926, 2927, 2928, 2929, 2930, 2931, 2932,
#        2933, 2934, 2935, 2936, 2937, 2938, 2939, 2940, 2941, 2942, 2943,
#        2944, 2945, 2946, 2947, 2948, 2949, 2950, 2951, 2952, 2953, 2954,
#        2955, 2956, 2957, 2958, 2959, 2960, 2961, 2962, 2963, 2964, 2965,
#        2966, 2967, 2968, 2969, 2970, 2971, 2972, 2973, 2974, 2975, 2976,
#        2977, 2978, 2979, 2980, 2981, 2982, 2983, 2984, 2985, 2986, 2987,
#        2988, 2989, 2990, 2991, 2992, 2993, 2994, 2995, 2996, 2997, 2998,
#        2999, 3000, 3001, 3002, 3003, 3004, 3005, 3006, 3007, 3008, 3009,
#        3010, 3011, 3012, 3013, 3014, 3015, 3016, 3017, 3018, 3019, 3020,
#        3021, 3022, 3023, 3024, 3025, 3026, 3027, 3028, 3029, 3030, 3031,
#        3032, 3033, 3034, 3035, 3036, 3037, 3038, 3039, 3040, 3041, 3042,
#        3043, 3044, 3045, 3046, 3047, 3048, 3049, 3050, 3051, 3052, 3053,
#        3054, 3055, 3056, 3057, 3058, 3059, 3060, 3061, 3062, 3063, 3064,
#        3065, 3066, 3067, 3068, 3069, 3070, 3071, 3072, 3073, 3074, 3075,
#        3076, 3077, 3078, 3079, 3080, 3081, 3082, 3083, 3084, 3085, 3086,
#        3087, 3088, 3089, 3090, 3091, 3092]),)

# %% [markdown]
# ## Graficamos ahora las anomalías.

# %% [markdown]
# Ahora ya conocemos las muestras de los datos que son anomalías. Con esto, encontraremos las `timestamps` correspondientes a partir de los datos originales de prueba. Usaremos el siguiente método para hacerlo:
#
# Supongamos que `time_steps = 3` y tenemos `10 valores de entrenamiento.` Nuestro `x_train` se verá así:
#
# - 0, 1, 2
# - 1, 2, 3
# - 2, 3, 4
# - 3, 4, 5
# - 4, 5, 6
# - 5, 6, 7
# - 6, 7, 8
# - 7, 8, 9
#
# Excepto los valores iniciales y finales (time_steps - 1), todos los demás aparecerán en time_steps muestras distintas.
#
# Por lo tanto, si sabemos que las muestras `[(3, 4, 5), (4, 5, 6), (5, 6, 7)]` son anomalías, podemos decir que el punto de dato 5 es una anomalía.

# %%
anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)

# %%
df_subset = df_daily_jumpsup.iloc[anomalous_data_indices]

fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)

if len(anomalous_data_indices) > 0:
    df_subset.plot(legend=False, ax=ax, color="r")
else:
    print("anomalous_data_indices está vacío: no hay anomalías que graficar.")

plt.show()
